# %%
from virtual_accelerator.models.cu_hxr import get_cu_inj_impact_model
model = get_cu_inj_impact_model()
# Out:
# Element type solrf for element GUN not found in variable configuration mapping. Skipping.
# Element type solrf for element SOL1 not found in variable configuration mapping. Skipping.
# Screen YAG02 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type solrf for element L0A_entrance not found in variable configuration mapping. Skipping.
# Element type solrf for element L0A_body_1 not found in variable configuration mapping. Skipping.
# Element type solrf for element L0A_body_2 not found in variable configuration mapping. Skipping.
# Element type solrf for element L0A_exit not found in variable configuration mapping. Skipping.
# Screen YAG03 found in lattice but missing from screen configuration. Skipping screen variables for this element.
# Element type solrf for element L0B_entrance not found in variable configuration mapping. Skipping.
# Element type solrf for element L0B_body_1 not found in variable configuration mapping. Skipping.
# Element type solrf for element L0B_body_2 not found in variable configuration mapping. Skipping.
# Element type solrf for element L0B_exit not found in variable configuration mapping. Skipping.
# Screen OTR1 found in lattice but missing from screen configuration. Skipping screen variables for this element.

# %%
model.supported_variables
# Out:
# {'distgen:n_particle': DistgenInputAction(name='distgen:n_particle', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit=None, key='n_particle'),
#  'distgen:total_charge': DistgenInputAction(name='distgen:total_charge', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='picocoulomb', key='total_charge:value'),
#  'distgen:start:cathode:MTE': DistgenInputAction(name='distgen:start:cathode:MTE', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='millielectron_volt', key='start:MTE:value'),
#  'distgen:r_dist:sigma_xy': DistgenInputAction(name='distgen:r_dist:sigma_xy', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='millimeter', key='r_dist:sigma_xy:value'),
#  'distgen:t_dist:length': DistgenInputAction(name='distgen:t_dist:length', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='picosecond', key='t_dist:length:value'),
#  'distgen:t_dist:ratio': DistgenInputAction(name='distgen:t_dist:ratio', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='dimensionless', key='t_dist:ratio:value'),
#  'header:Npcol': HeaderAction(name='header:Npcol', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Npcol'),
#  'header:Nprow': HeaderAction(name='header:Nprow', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Nprow'),
#  'header:Dt': HeaderAction(name='header:Dt', read_only=False, default_validation_config='none', default_value=5e-13, value_range=None, unit='s', key='Dt'),
#  'header:Ntstep': HeaderAction(name='header:Ntstep', read_only=False, default_validation_config='none', default_value=1000000.0, value_range=None, unit=None, key='Ntstep'),
#  'header:Nbunch': HeaderAction(name='header:Nbunch', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Nbunch'),
#  'header:Np': HeaderAction(name='header:Np', read_only=False, default_validation_config='none', default_value=100.0, value_range=None, unit=None, key='Np'),
#  'header:Bcurr': HeaderAction(name='header:Bcurr', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='A', key='Bcurr'),
#  'header:Bkenergy': HeaderAction(name='header:Bkenergy', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit='eV', key='Bkenergy'),
#  'header:Bmass': HeaderAction(name='header:Bmass', read_only=False, default_validation_config='none', default_value=511005.0, value_range=None, unit='eV', key='Bmass'),
#  'header:Bcharge': HeaderAction(name='header:Bcharge', read_only=False, default_validation_config='none', default_value=-1.0, value_range=None, unit=None, key='Bcharge'),
#  'header:Bfreq': HeaderAction(name='header:Bfreq', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', key='Bfreq'),
#  'header:Tini': HeaderAction(name='header:Tini', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='s', key='Tini'),
#  'header:Flagmap': HeaderAction(name='header:Flagmap', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Flagmap'),
#  'header:Flagerr': HeaderAction(name='header:Flagerr', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='Flagerr'),
#  'header:Flagdiag': HeaderAction(name='header:Flagdiag', read_only=False, default_validation_config='none', default_value=2.0, value_range=None, unit=None, key='Flagdiag'),
#  'header:Flagimg': HeaderAction(name='header:Flagimg', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Flagimg'),
#  'header:Flagdist': HeaderAction(name='header:Flagdist', read_only=False, default_validation_config='none', default_value=16.0, value_range=None, unit=None, key='Flagdist'),
#  'header:Flagbc': HeaderAction(name='header:Flagbc', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='Flagbc'),
#  'header:Rstartflg': HeaderAction(name='header:Rstartflg', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='Rstartflg'),
#  'header:Flagsbstp': HeaderAction(name='header:Flagsbstp', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='Flagsbstp'),
#  'header:Dim': HeaderAction(name='header:Dim', read_only=False, default_validation_config='none', default_value=6.0, value_range=None, unit=None, key='Dim'),
#  'header:Nx': HeaderAction(name='header:Nx', read_only=False, default_validation_config='none', default_value=32.0, value_range=None, unit=None, key='Nx'),
#  'header:Ny': HeaderAction(name='header:Ny', read_only=False, default_validation_config='none', default_value=32.0, value_range=None, unit=None, key='Ny'),
#  'header:Nz': HeaderAction(name='header:Nz', read_only=False, default_validation_config='none', default_value=32.0, value_range=None, unit=None, key='Nz'),
#  'header:Xrad': HeaderAction(name='header:Xrad', read_only=False, default_validation_config='none', default_value=0.015, value_range=None, unit='m', key='Xrad'),
#  'header:Yrad': HeaderAction(name='header:Yrad', read_only=False, default_validation_config='none', default_value=0.015, value_range=None, unit='m', key='Yrad'),
#  'header:Perdlen': HeaderAction(name='header:Perdlen', read_only=False, default_validation_config='none', default_value=45.0, value_range=None, unit='m', key='Perdlen'),
#  'header:Zimage': HeaderAction(name='header:Zimage', read_only=False, default_validation_config='none', default_value=0.02, value_range=None, unit='m', key='Zimage'),
#  'header:Nemission': HeaderAction(name='header:Nemission', read_only=False, default_validation_config='none', default_value=400.0, value_range=None, unit=None, key='Nemission'),
#  'header:Temission': HeaderAction(name='header:Temission', read_only=False, default_validation_config='none', default_value=1.4e-11, value_range=None, unit='s', key='Temission'),
#  'header:sigx': HeaderAction(name='header:sigx', read_only=False, default_validation_config='none', default_value=0.0006, value_range=None, unit='m', key='sigx'),
#  'header:sigpx': HeaderAction(name='header:sigpx', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='sigpx'),
#  'header:muxpx': HeaderAction(name='header:muxpx', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='muxpx'),
#  'header:xscale': HeaderAction(name='header:xscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='xscale'),
#  'header:pxscale': HeaderAction(name='header:pxscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='pxscale'),
#  'header:xmu1': HeaderAction(name='header:xmu1', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', key='xmu1'),
#  'header:xmu2': HeaderAction(name='header:xmu2', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='xmu2'),
#  'header:sigy': HeaderAction(name='header:sigy', read_only=False, default_validation_config='none', default_value=0.0006, value_range=None, unit='m', key='sigy'),
#  'header:sigpy': HeaderAction(name='header:sigpy', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='sigpy'),
#  'header:muxpy': HeaderAction(name='header:muxpy', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='muxpy'),
#  'header:yscale': HeaderAction(name='header:yscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='yscale'),
#  'header:pyscale': HeaderAction(name='header:pyscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='pyscale'),
#  'header:ymu1': HeaderAction(name='header:ymu1', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', key='ymu1'),
#  'header:ymu2': HeaderAction(name='header:ymu2', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='ymu2'),
#  'header:sigz': HeaderAction(name='header:sigz', read_only=False, default_validation_config='none', default_value=1.27e-06, value_range=None, unit='m', key='sigz'),
#  'header:sigpz': HeaderAction(name='header:sigpz', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='sigpz'),
#  'header:muxpz': HeaderAction(name='header:muxpz', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='muxpz'),
#  'header:zscale': HeaderAction(name='header:zscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='zscale'),
#  'header:pzscale': HeaderAction(name='header:pzscale', read_only=False, default_validation_config='none', default_value=1.0, value_range=None, unit=None, key='pzscale'),
#  'header:zmu1': HeaderAction(name='header:zmu1', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', key='zmu1'),
#  'header:zmu2': HeaderAction(name='header:zmu2', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, key='zmu2'),
#  'ele:GUN:rf_field_scale': ScalarEleAction(name='ele:GUN:rf_field_scale', read_only=False, default_validation_config='none', default_value=47537665.059089914, value_range=None, unit=None, ele_name='GUN', attribute='rf_field_scale'),
#  'ele:GUN:rf_frequency': ScalarEleAction(name='ele:GUN:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='GUN', attribute='rf_frequency'),
#  'ele:GUN:theta0_deg': ScalarEleAction(name='ele:GUN:theta0_deg', read_only=False, default_validation_config='none', default_value=303.93723122804266, value_range=None, unit='deg', ele_name='GUN', attribute='theta0_deg'),
#  'ele:GUN:radius': ScalarEleAction(name='ele:GUN:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='GUN', attribute='radius'),
#  'ele:GUN:solenoid_field_scale': ScalarEleAction(name='ele:GUN:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='GUN', attribute='solenoid_field_scale'),
#  'ele:GUN:x_offset': ScalarEleAction(name='ele:GUN:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='GUN', attribute='x_offset'),
#  'ele:GUN:y_offset': ScalarEleAction(name='ele:GUN:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='GUN', attribute='y_offset'),
#  'ele:GUN:x_rotation': ScalarEleAction(name='ele:GUN:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='GUN', attribute='x_rotation'),
#  'ele:GUN:y_rotation': ScalarEleAction(name='ele:GUN:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='GUN', attribute='y_rotation'),
#  'ele:GUN:z_rotation': ScalarEleAction(name='ele:GUN:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='GUN', attribute='z_rotation'),
#  'ele:SOL1:rf_field_scale': ScalarEleAction(name='ele:SOL1:rf_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='SOL1', attribute='rf_field_scale'),
#  'ele:SOL1:rf_frequency': ScalarEleAction(name='ele:SOL1:rf_frequency', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='Hz', ele_name='SOL1', attribute='rf_frequency'),
#  'ele:SOL1:theta0_deg': ScalarEleAction(name='ele:SOL1:theta0_deg', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='deg', ele_name='SOL1', attribute='theta0_deg'),
#  'ele:SOL1:radius': ScalarEleAction(name='ele:SOL1:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='SOL1', attribute='radius'),
#  'ele:SOL1:solenoid_field_scale': ScalarEleAction(name='ele:SOL1:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.2457, value_range=None, unit=None, ele_name='SOL1', attribute='solenoid_field_scale'),
#  'ele:SOL1:x_offset': ScalarEleAction(name='ele:SOL1:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='SOL1', attribute='x_offset'),
#  'ele:SOL1:y_offset': ScalarEleAction(name='ele:SOL1:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='SOL1', attribute='y_offset'),
#  'ele:SOL1:x_rotation': ScalarEleAction(name='ele:SOL1:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='SOL1', attribute='x_rotation'),
#  'ele:SOL1:y_rotation': ScalarEleAction(name='ele:SOL1:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='SOL1', attribute='y_rotation'),
#  'ele:SOL1:z_rotation': ScalarEleAction(name='ele:SOL1:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='SOL1', attribute='z_rotation'),
#  'ele:SQ01:b1_gradient': ScalarEleAction(name='ele:SQ01:b1_gradient', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='T/m', ele_name='SQ01', attribute='b1_gradient'),
#  'ele:SQ01:L_effective': ScalarEleAction(name='ele:SQ01:L_effective', read_only=False, default_validation_config='none', default_value=0.21, value_range=None, unit='m', ele_name='SQ01', attribute='L_effective'),
#  'ele:SQ01:radius': ScalarEleAction(name='ele:SQ01:radius', read_only=False, default_validation_config='none', default_value=0.0254, value_range=None, unit='m', ele_name='SQ01', attribute='radius'),
#  'ele:SQ01:x_offset': ScalarEleAction(name='ele:SQ01:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='SQ01', attribute='x_offset'),
#  'ele:SQ01:y_offset': ScalarEleAction(name='ele:SQ01:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='SQ01', attribute='y_offset'),
#  'ele:SQ01:x_rotation': ScalarEleAction(name='ele:SQ01:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='SQ01', attribute='x_rotation'),
#  'ele:SQ01:y_rotation': ScalarEleAction(name='ele:SQ01:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='SQ01', attribute='y_rotation'),
#  'ele:SQ01:z_rotation': ScalarEleAction(name='ele:SQ01:z_rotation', read_only=False, default_validation_config='none', default_value=0.7853981633974483, value_range=None, unit='rad', ele_name='SQ01', attribute='z_rotation'),
#  'ele:CQ01:b1_gradient': ScalarEleAction(name='ele:CQ01:b1_gradient', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='T/m', ele_name='CQ01', attribute='b1_gradient'),
#  'ele:CQ01:L_effective': ScalarEleAction(name='ele:CQ01:L_effective', read_only=False, default_validation_config='none', default_value=0.21, value_range=None, unit='m', ele_name='CQ01', attribute='L_effective'),
#  'ele:CQ01:radius': ScalarEleAction(name='ele:CQ01:radius', read_only=False, default_validation_config='none', default_value=0.0254, value_range=None, unit='m', ele_name='CQ01', attribute='radius'),
#  'ele:CQ01:x_offset': ScalarEleAction(name='ele:CQ01:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='CQ01', attribute='x_offset'),
#  'ele:CQ01:y_offset': ScalarEleAction(name='ele:CQ01:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='CQ01', attribute='y_offset'),
#  'ele:CQ01:x_rotation': ScalarEleAction(name='ele:CQ01:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='CQ01', attribute='x_rotation'),
#  'ele:CQ01:y_rotation': ScalarEleAction(name='ele:CQ01:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='CQ01', attribute='y_rotation'),
#  'ele:CQ01:z_rotation': ScalarEleAction(name='ele:CQ01:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='CQ01', attribute='z_rotation'),
#  'ele:L0A_entrance:rf_field_scale': ScalarEleAction(name='ele:L0A_entrance:rf_field_scale', read_only=False, default_validation_config='none', default_value=26013439.060000002, value_range=None, unit=None, ele_name='L0A_entrance', attribute='rf_field_scale'),
#  'ele:L0A_entrance:rf_frequency': ScalarEleAction(name='ele:L0A_entrance:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0A_entrance', attribute='rf_frequency'),
#  'ele:L0A_entrance:theta0_deg': ScalarEleAction(name='ele:L0A_entrance:theta0_deg', read_only=False, default_validation_config='none', default_value=264.5, value_range=None, unit='deg', ele_name='L0A_entrance', attribute='theta0_deg'),
#  'ele:L0A_entrance:radius': ScalarEleAction(name='ele:L0A_entrance:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0A_entrance', attribute='radius'),
#  'ele:L0A_entrance:solenoid_field_scale': ScalarEleAction(name='ele:L0A_entrance:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0A_entrance', attribute='solenoid_field_scale'),
#  'ele:L0A_entrance:x_offset': ScalarEleAction(name='ele:L0A_entrance:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_entrance', attribute='x_offset'),
#  'ele:L0A_entrance:y_offset': ScalarEleAction(name='ele:L0A_entrance:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_entrance', attribute='y_offset'),
#  'ele:L0A_entrance:x_rotation': ScalarEleAction(name='ele:L0A_entrance:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_entrance', attribute='x_rotation'),
#  'ele:L0A_entrance:y_rotation': ScalarEleAction(name='ele:L0A_entrance:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_entrance', attribute='y_rotation'),
#  'ele:L0A_entrance:z_rotation': ScalarEleAction(name='ele:L0A_entrance:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_entrance', attribute='z_rotation'),
#  'ele:L0A_body_1:rf_field_scale': ScalarEleAction(name='ele:L0A_body_1:rf_field_scale', read_only=False, default_validation_config='none', default_value=30048347.1, value_range=None, unit=None, ele_name='L0A_body_1', attribute='rf_field_scale'),
#  'ele:L0A_body_1:rf_frequency': ScalarEleAction(name='ele:L0A_body_1:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0A_body_1', attribute='rf_frequency'),
#  'ele:L0A_body_1:theta0_deg': ScalarEleAction(name='ele:L0A_body_1:theta0_deg', read_only=False, default_validation_config='none', default_value=294.5, value_range=None, unit='deg', ele_name='L0A_body_1', attribute='theta0_deg'),
#  'ele:L0A_body_1:radius': ScalarEleAction(name='ele:L0A_body_1:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0A_body_1', attribute='radius'),
#  'ele:L0A_body_1:solenoid_field_scale': ScalarEleAction(name='ele:L0A_body_1:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0A_body_1', attribute='solenoid_field_scale'),
#  'ele:L0A_body_1:x_offset': ScalarEleAction(name='ele:L0A_body_1:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_body_1', attribute='x_offset'),
#  'ele:L0A_body_1:y_offset': ScalarEleAction(name='ele:L0A_body_1:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_body_1', attribute='y_offset'),
#  'ele:L0A_body_1:x_rotation': ScalarEleAction(name='ele:L0A_body_1:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_1', attribute='x_rotation'),
#  'ele:L0A_body_1:y_rotation': ScalarEleAction(name='ele:L0A_body_1:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_1', attribute='y_rotation'),
#  'ele:L0A_body_1:z_rotation': ScalarEleAction(name='ele:L0A_body_1:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_1', attribute='z_rotation'),
#  'ele:L0A_body_2:rf_field_scale': ScalarEleAction(name='ele:L0A_body_2:rf_field_scale', read_only=False, default_validation_config='none', default_value=30048347.1, value_range=None, unit=None, ele_name='L0A_body_2', attribute='rf_field_scale'),
#  'ele:L0A_body_2:rf_frequency': ScalarEleAction(name='ele:L0A_body_2:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0A_body_2', attribute='rf_frequency'),
#  'ele:L0A_body_2:theta0_deg': ScalarEleAction(name='ele:L0A_body_2:theta0_deg', read_only=False, default_validation_config='none', default_value=354.5, value_range=None, unit='deg', ele_name='L0A_body_2', attribute='theta0_deg'),
#  'ele:L0A_body_2:radius': ScalarEleAction(name='ele:L0A_body_2:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0A_body_2', attribute='radius'),
#  'ele:L0A_body_2:solenoid_field_scale': ScalarEleAction(name='ele:L0A_body_2:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0A_body_2', attribute='solenoid_field_scale'),
#  'ele:L0A_body_2:x_offset': ScalarEleAction(name='ele:L0A_body_2:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_body_2', attribute='x_offset'),
#  'ele:L0A_body_2:y_offset': ScalarEleAction(name='ele:L0A_body_2:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_body_2', attribute='y_offset'),
#  'ele:L0A_body_2:x_rotation': ScalarEleAction(name='ele:L0A_body_2:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_2', attribute='x_rotation'),
#  'ele:L0A_body_2:y_rotation': ScalarEleAction(name='ele:L0A_body_2:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_2', attribute='y_rotation'),
#  'ele:L0A_body_2:z_rotation': ScalarEleAction(name='ele:L0A_body_2:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_body_2', attribute='z_rotation'),
#  'ele:L0A_exit:rf_field_scale': ScalarEleAction(name='ele:L0A_exit:rf_field_scale', read_only=False, default_validation_config='none', default_value=26013439.060000002, value_range=None, unit=None, ele_name='L0A_exit', attribute='rf_field_scale'),
#  'ele:L0A_exit:rf_frequency': ScalarEleAction(name='ele:L0A_exit:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0A_exit', attribute='rf_frequency'),
#  'ele:L0A_exit:theta0_deg': ScalarEleAction(name='ele:L0A_exit:theta0_deg', read_only=False, default_validation_config='none', default_value=264.5, value_range=None, unit='deg', ele_name='L0A_exit', attribute='theta0_deg'),
#  'ele:L0A_exit:radius': ScalarEleAction(name='ele:L0A_exit:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0A_exit', attribute='radius'),
#  'ele:L0A_exit:solenoid_field_scale': ScalarEleAction(name='ele:L0A_exit:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0A_exit', attribute='solenoid_field_scale'),
#  'ele:L0A_exit:x_offset': ScalarEleAction(name='ele:L0A_exit:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_exit', attribute='x_offset'),
#  'ele:L0A_exit:y_offset': ScalarEleAction(name='ele:L0A_exit:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0A_exit', attribute='y_offset'),
#  'ele:L0A_exit:x_rotation': ScalarEleAction(name='ele:L0A_exit:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_exit', attribute='x_rotation'),
#  'ele:L0A_exit:y_rotation': ScalarEleAction(name='ele:L0A_exit:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_exit', attribute='y_rotation'),
#  'ele:L0A_exit:z_rotation': ScalarEleAction(name='ele:L0A_exit:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0A_exit', attribute='z_rotation'),
#  'ele:QA01:b1_gradient': ScalarEleAction(name='ele:QA01:b1_gradient', read_only=False, default_validation_config='none', default_value=1.8524000101358, value_range=None, unit='T/m', ele_name='QA01', attribute='b1_gradient'),
#  'ele:QA01:L_effective': ScalarEleAction(name='ele:QA01:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QA01', attribute='L_effective'),
#  'ele:QA01:radius': ScalarEleAction(name='ele:QA01:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QA01', attribute='radius'),
#  'ele:QA01:x_offset': ScalarEleAction(name='ele:QA01:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QA01', attribute='x_offset'),
#  'ele:QA01:y_offset': ScalarEleAction(name='ele:QA01:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QA01', attribute='y_offset'),
#  'ele:QA01:x_rotation': ScalarEleAction(name='ele:QA01:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA01', attribute='x_rotation'),
#  'ele:QA01:y_rotation': ScalarEleAction(name='ele:QA01:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA01', attribute='y_rotation'),
#  'ele:QA01:z_rotation': ScalarEleAction(name='ele:QA01:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA01', attribute='z_rotation'),
#  'ele:QA02:b1_gradient': ScalarEleAction(name='ele:QA02:b1_gradient', read_only=False, default_validation_config='none', default_value=-1.8524000101358, value_range=None, unit='T/m', ele_name='QA02', attribute='b1_gradient'),
#  'ele:QA02:L_effective': ScalarEleAction(name='ele:QA02:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QA02', attribute='L_effective'),
#  'ele:QA02:radius': ScalarEleAction(name='ele:QA02:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QA02', attribute='radius'),
#  'ele:QA02:x_offset': ScalarEleAction(name='ele:QA02:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QA02', attribute='x_offset'),
#  'ele:QA02:y_offset': ScalarEleAction(name='ele:QA02:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QA02', attribute='y_offset'),
#  'ele:QA02:x_rotation': ScalarEleAction(name='ele:QA02:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA02', attribute='x_rotation'),
#  'ele:QA02:y_rotation': ScalarEleAction(name='ele:QA02:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA02', attribute='y_rotation'),
#  'ele:QA02:z_rotation': ScalarEleAction(name='ele:QA02:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QA02', attribute='z_rotation'),
#  'ele:L0B_entrance:rf_field_scale': ScalarEleAction(name='ele:L0B_entrance:rf_field_scale', read_only=False, default_validation_config='none', default_value=31395529.900000002, value_range=None, unit=None, ele_name='L0B_entrance', attribute='rf_field_scale'),
#  'ele:L0B_entrance:rf_frequency': ScalarEleAction(name='ele:L0B_entrance:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0B_entrance', attribute='rf_frequency'),
#  'ele:L0B_entrance:theta0_deg': ScalarEleAction(name='ele:L0B_entrance:theta0_deg', read_only=False, default_validation_config='none', default_value=42.27, value_range=None, unit='deg', ele_name='L0B_entrance', attribute='theta0_deg'),
#  'ele:L0B_entrance:radius': ScalarEleAction(name='ele:L0B_entrance:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0B_entrance', attribute='radius'),
#  'ele:L0B_entrance:solenoid_field_scale': ScalarEleAction(name='ele:L0B_entrance:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0B_entrance', attribute='solenoid_field_scale'),
#  'ele:L0B_entrance:x_offset': ScalarEleAction(name='ele:L0B_entrance:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_entrance', attribute='x_offset'),
#  'ele:L0B_entrance:y_offset': ScalarEleAction(name='ele:L0B_entrance:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_entrance', attribute='y_offset'),
#  'ele:L0B_entrance:x_rotation': ScalarEleAction(name='ele:L0B_entrance:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_entrance', attribute='x_rotation'),
#  'ele:L0B_entrance:y_rotation': ScalarEleAction(name='ele:L0B_entrance:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_entrance', attribute='y_rotation'),
#  'ele:L0B_entrance:z_rotation': ScalarEleAction(name='ele:L0B_entrance:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_entrance', attribute='z_rotation'),
#  'ele:L0B_body_1:rf_field_scale': ScalarEleAction(name='ele:L0B_body_1:rf_field_scale', read_only=False, default_validation_config='none', default_value=36265246.5, value_range=None, unit=None, ele_name='L0B_body_1', attribute='rf_field_scale'),
#  'ele:L0B_body_1:rf_frequency': ScalarEleAction(name='ele:L0B_body_1:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0B_body_1', attribute='rf_frequency'),
#  'ele:L0B_body_1:theta0_deg': ScalarEleAction(name='ele:L0B_body_1:theta0_deg', read_only=False, default_validation_config='none', default_value=72.27, value_range=None, unit='deg', ele_name='L0B_body_1', attribute='theta0_deg'),
#  'ele:L0B_body_1:radius': ScalarEleAction(name='ele:L0B_body_1:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0B_body_1', attribute='radius'),
#  'ele:L0B_body_1:solenoid_field_scale': ScalarEleAction(name='ele:L0B_body_1:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0B_body_1', attribute='solenoid_field_scale'),
#  'ele:L0B_body_1:x_offset': ScalarEleAction(name='ele:L0B_body_1:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_body_1', attribute='x_offset'),
#  'ele:L0B_body_1:y_offset': ScalarEleAction(name='ele:L0B_body_1:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_body_1', attribute='y_offset'),
#  'ele:L0B_body_1:x_rotation': ScalarEleAction(name='ele:L0B_body_1:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_1', attribute='x_rotation'),
#  'ele:L0B_body_1:y_rotation': ScalarEleAction(name='ele:L0B_body_1:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_1', attribute='y_rotation'),
#  'ele:L0B_body_1:z_rotation': ScalarEleAction(name='ele:L0B_body_1:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_1', attribute='z_rotation'),
#  'ele:L0B_body_2:rf_field_scale': ScalarEleAction(name='ele:L0B_body_2:rf_field_scale', read_only=False, default_validation_config='none', default_value=36265246.5, value_range=None, unit=None, ele_name='L0B_body_2', attribute='rf_field_scale'),
#  'ele:L0B_body_2:rf_frequency': ScalarEleAction(name='ele:L0B_body_2:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0B_body_2', attribute='rf_frequency'),
#  'ele:L0B_body_2:theta0_deg': ScalarEleAction(name='ele:L0B_body_2:theta0_deg', read_only=False, default_validation_config='none', default_value=132.27, value_range=None, unit='deg', ele_name='L0B_body_2', attribute='theta0_deg'),
#  'ele:L0B_body_2:radius': ScalarEleAction(name='ele:L0B_body_2:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0B_body_2', attribute='radius'),
#  'ele:L0B_body_2:solenoid_field_scale': ScalarEleAction(name='ele:L0B_body_2:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0B_body_2', attribute='solenoid_field_scale'),
#  'ele:L0B_body_2:x_offset': ScalarEleAction(name='ele:L0B_body_2:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_body_2', attribute='x_offset'),
#  'ele:L0B_body_2:y_offset': ScalarEleAction(name='ele:L0B_body_2:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_body_2', attribute='y_offset'),
#  'ele:L0B_body_2:x_rotation': ScalarEleAction(name='ele:L0B_body_2:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_2', attribute='x_rotation'),
#  'ele:L0B_body_2:y_rotation': ScalarEleAction(name='ele:L0B_body_2:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_2', attribute='y_rotation'),
#  'ele:L0B_body_2:z_rotation': ScalarEleAction(name='ele:L0B_body_2:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_body_2', attribute='z_rotation'),
#  'ele:L0B_exit:rf_field_scale': ScalarEleAction(name='ele:L0B_exit:rf_field_scale', read_only=False, default_validation_config='none', default_value=31395529.900000002, value_range=None, unit=None, ele_name='L0B_exit', attribute='rf_field_scale'),
#  'ele:L0B_exit:rf_frequency': ScalarEleAction(name='ele:L0B_exit:rf_frequency', read_only=False, default_validation_config='none', default_value=2856000000.0, value_range=None, unit='Hz', ele_name='L0B_exit', attribute='rf_frequency'),
#  'ele:L0B_exit:theta0_deg': ScalarEleAction(name='ele:L0B_exit:theta0_deg', read_only=False, default_validation_config='none', default_value=42.27, value_range=None, unit='deg', ele_name='L0B_exit', attribute='theta0_deg'),
#  'ele:L0B_exit:radius': ScalarEleAction(name='ele:L0B_exit:radius', read_only=False, default_validation_config='none', default_value=0.15, value_range=None, unit='m', ele_name='L0B_exit', attribute='radius'),
#  'ele:L0B_exit:solenoid_field_scale': ScalarEleAction(name='ele:L0B_exit:solenoid_field_scale', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit=None, ele_name='L0B_exit', attribute='solenoid_field_scale'),
#  'ele:L0B_exit:x_offset': ScalarEleAction(name='ele:L0B_exit:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_exit', attribute='x_offset'),
#  'ele:L0B_exit:y_offset': ScalarEleAction(name='ele:L0B_exit:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='L0B_exit', attribute='y_offset'),
#  'ele:L0B_exit:x_rotation': ScalarEleAction(name='ele:L0B_exit:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_exit', attribute='x_rotation'),
#  'ele:L0B_exit:y_rotation': ScalarEleAction(name='ele:L0B_exit:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_exit', attribute='y_rotation'),
#  'ele:L0B_exit:z_rotation': ScalarEleAction(name='ele:L0B_exit:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='L0B_exit', attribute='z_rotation'),
#  'ele:QE01:b1_gradient': ScalarEleAction(name='ele:QE01:b1_gradient', read_only=False, default_validation_config='none', default_value=0.18720000156206, value_range=None, unit='T/m', ele_name='QE01', attribute='b1_gradient'),
#  'ele:QE01:L_effective': ScalarEleAction(name='ele:QE01:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QE01', attribute='L_effective'),
#  'ele:QE01:radius': ScalarEleAction(name='ele:QE01:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QE01', attribute='radius'),
#  'ele:QE01:x_offset': ScalarEleAction(name='ele:QE01:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE01', attribute='x_offset'),
#  'ele:QE01:y_offset': ScalarEleAction(name='ele:QE01:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE01', attribute='y_offset'),
#  'ele:QE01:x_rotation': ScalarEleAction(name='ele:QE01:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE01', attribute='x_rotation'),
#  'ele:QE01:y_rotation': ScalarEleAction(name='ele:QE01:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE01', attribute='y_rotation'),
#  'ele:QE01:z_rotation': ScalarEleAction(name='ele:QE01:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE01', attribute='z_rotation'),
#  'ele:QE02:b1_gradient': ScalarEleAction(name='ele:QE02:b1_gradient', read_only=False, default_validation_config='none', default_value=0.16609999999321, value_range=None, unit='T/m', ele_name='QE02', attribute='b1_gradient'),
#  'ele:QE02:L_effective': ScalarEleAction(name='ele:QE02:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QE02', attribute='L_effective'),
#  'ele:QE02:radius': ScalarEleAction(name='ele:QE02:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QE02', attribute='radius'),
#  'ele:QE02:x_offset': ScalarEleAction(name='ele:QE02:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE02', attribute='x_offset'),
#  'ele:QE02:y_offset': ScalarEleAction(name='ele:QE02:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE02', attribute='y_offset'),
#  'ele:QE02:x_rotation': ScalarEleAction(name='ele:QE02:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE02', attribute='x_rotation'),
#  'ele:QE02:y_rotation': ScalarEleAction(name='ele:QE02:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE02', attribute='y_rotation'),
#  'ele:QE02:z_rotation': ScalarEleAction(name='ele:QE02:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE02', attribute='z_rotation'),
#  'ele:QE03:b1_gradient': ScalarEleAction(name='ele:QE03:b1_gradient', read_only=False, default_validation_config='none', default_value=-2.6409000012747, value_range=None, unit='T/m', ele_name='QE03', attribute='b1_gradient'),
#  'ele:QE03:L_effective': ScalarEleAction(name='ele:QE03:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QE03', attribute='L_effective'),
#  'ele:QE03:radius': ScalarEleAction(name='ele:QE03:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QE03', attribute='radius'),
#  'ele:QE03:x_offset': ScalarEleAction(name='ele:QE03:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE03', attribute='x_offset'),
#  'ele:QE03:y_offset': ScalarEleAction(name='ele:QE03:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE03', attribute='y_offset'),
#  'ele:QE03:x_rotation': ScalarEleAction(name='ele:QE03:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE03', attribute='x_rotation'),
#  'ele:QE03:y_rotation': ScalarEleAction(name='ele:QE03:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE03', attribute='y_rotation'),
#  'ele:QE03:z_rotation': ScalarEleAction(name='ele:QE03:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE03', attribute='z_rotation'),
#  'ele:QE04:b1_gradient': ScalarEleAction(name='ele:QE04:b1_gradient', read_only=False, default_validation_config='none', default_value=2.9799999853198, value_range=None, unit='T/m', ele_name='QE04', attribute='b1_gradient'),
#  'ele:QE04:L_effective': ScalarEleAction(name='ele:QE04:L_effective', read_only=False, default_validation_config='none', default_value=0.108, value_range=None, unit='m', ele_name='QE04', attribute='L_effective'),
#  'ele:QE04:radius': ScalarEleAction(name='ele:QE04:radius', read_only=False, default_validation_config='none', default_value=0.016, value_range=None, unit='m', ele_name='QE04', attribute='radius'),
#  'ele:QE04:x_offset': ScalarEleAction(name='ele:QE04:x_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE04', attribute='x_offset'),
#  'ele:QE04:y_offset': ScalarEleAction(name='ele:QE04:y_offset', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='m', ele_name='QE04', attribute='y_offset'),
#  'ele:QE04:x_rotation': ScalarEleAction(name='ele:QE04:x_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE04', attribute='x_rotation'),
#  'ele:QE04:y_rotation': ScalarEleAction(name='ele:QE04:y_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE04', attribute='y_rotation'),
#  'ele:QE04:z_rotation': ScalarEleAction(name='ele:QE04:z_rotation', read_only=False, default_validation_config='none', default_value=0.0, value_range=None, unit='rad', ele_name='QE04', attribute='z_rotation'),
#  'stat:mean_kinetic_energy': StatAction(name='stat:mean_kinetic_energy', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([0.58531347, 0.58531347, 0.58531347, ...,        nan,        nan,
#                nan], shape=(3443,)), unit='eV', stat_name='mean_kinetic_energy'),
#  'stat:mean_x': StatAction(name='stat:mean_x', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([0.00032717, 0.00032717, 0.00032717, ...,        nan,        nan,
#                nan], shape=(3443,)), unit='m', stat_name='mean_x'),
#  'stat:mean_y': StatAction(name='stat:mean_y', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([1.7774198e-06, 1.7774198e-06, 1.7774198e-06, ...,           nan,
#                   nan,           nan], shape=(3443,)), unit='m', stat_name='mean_y'),
#  'stat:mean_z': StatAction(name='stat:mean_z', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([-1.9521438e-06, -1.8483526e-06, -1.7445614e-06, ...,
#                    nan,            nan,            nan], shape=(3443,)), unit='m', stat_name='mean_z'),
#  'stat:sigma_x': StatAction(name='stat:sigma_x', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([0.00013555, 0.00013555, 0.00013555, ...,        nan,        nan,
#                nan], shape=(3443,)), unit='m', stat_name='sigma_x'),
#  'stat:sigma_y': StatAction(name='stat:sigma_y', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([1.0466377e-05, 1.0466377e-05, 1.0466377e-05, ...,           nan,
#                   nan,           nan], shape=(3443,)), unit='m', stat_name='sigma_y'),
#  'stat:sigma_z': StatAction(name='stat:sigma_z', read_only=True, default_validation_config='none', shape=(3443,), dtype=dtype('float64'), default_value=array([7.5850693e-07, 7.5850693e-07, 7.5850693e-07, ...,           nan,
# ...
#  'particles:YAG02': ParticleGroupAction(name='particles:YAG02', read_only=True, default_validation_config='none', tool_name='YAG02'),
#  'particles:YAG03': ParticleGroupAction(name='particles:YAG03', read_only=True, default_validation_config='none', tool_name='YAG03'),
#  'particles:OTR1': ParticleGroupAction(name='particles:OTR1', read_only=True, default_validation_config='none', tool_name='OTR1'),
#  'particles:OTR2': ParticleGroupAction(name='particles:OTR2', read_only=True, default_validation_config='none', tool_name='OTR2'),
#  'QUAD:IN20:122:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:122:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='SQ01'),
#  'QUAD:IN20:122:BCTRL.DRVL': BminVariable(name='QUAD:IN20:122:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='SQ01'),
#  'QUAD:IN20:122:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:122:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='SQ01'),
#  'QUAD:IN20:122:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:122:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='SQ01'),
#  'QUAD:IN20:122:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:122:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='SQ01'),
#  'QUAD:IN20:122:BMAX': BmaxVariable(name='QUAD:IN20:122:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='SQ01'),
#  'QUAD:IN20:122:BMIN': BminVariable(name='QUAD:IN20:122:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='SQ01'),
#  'QUAD:IN20:122:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:122:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='SQ01'),
#  'QUAD:IN20:122:CTRL': ControlStateVariable(name='QUAD:IN20:122:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='SQ01'),
#  'QUAD:IN20:121:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:121:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='CQ01'),
#  'QUAD:IN20:121:BCTRL.DRVL': BminVariable(name='QUAD:IN20:121:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='CQ01'),
#  'QUAD:IN20:121:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:121:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='CQ01'),
#  'QUAD:IN20:121:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:121:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='CQ01'),
#  'QUAD:IN20:121:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:121:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='CQ01'),
#  'QUAD:IN20:121:BMAX': BmaxVariable(name='QUAD:IN20:121:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='CQ01'),
#  'QUAD:IN20:121:BMIN': BminVariable(name='QUAD:IN20:121:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='CQ01'),
#  'QUAD:IN20:121:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:121:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='CQ01'),
#  'QUAD:IN20:121:CTRL': ControlStateVariable(name='QUAD:IN20:121:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='CQ01'),
#  'QUAD:IN20:361:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:361:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA01'),
#  'QUAD:IN20:361:BCTRL.DRVL': BminVariable(name='QUAD:IN20:361:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA01'),
#  'QUAD:IN20:361:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:361:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA01'),
#  'QUAD:IN20:361:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:361:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA01'),
#  'QUAD:IN20:361:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:361:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA01'),
#  'QUAD:IN20:361:BMAX': BmaxVariable(name='QUAD:IN20:361:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA01'),
#  'QUAD:IN20:361:BMIN': BminVariable(name='QUAD:IN20:361:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA01'),
#  'QUAD:IN20:361:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:361:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA01'),
#  'QUAD:IN20:361:CTRL': ControlStateVariable(name='QUAD:IN20:361:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QA01'),
#  'QUAD:IN20:371:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:371:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA02'),
#  'QUAD:IN20:371:BCTRL.DRVL': BminVariable(name='QUAD:IN20:371:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA02'),
#  'QUAD:IN20:371:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:371:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA02'),
#  'QUAD:IN20:371:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:371:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA02'),
#  'QUAD:IN20:371:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:371:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QA02'),
#  'QUAD:IN20:371:BMAX': BmaxVariable(name='QUAD:IN20:371:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA02'),
#  'QUAD:IN20:371:BMIN': BminVariable(name='QUAD:IN20:371:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA02'),
#  'QUAD:IN20:371:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:371:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QA02'),
#  'QUAD:IN20:371:CTRL': ControlStateVariable(name='QUAD:IN20:371:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QA02'),
#  'QUAD:IN20:425:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:425:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE01'),
#  'QUAD:IN20:425:BCTRL.DRVL': BminVariable(name='QUAD:IN20:425:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE01'),
#  'QUAD:IN20:425:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:425:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE01'),
#  'QUAD:IN20:425:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:425:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE01'),
#  'QUAD:IN20:425:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:425:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE01'),
#  'QUAD:IN20:425:BMAX': BmaxVariable(name='QUAD:IN20:425:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE01'),
#  'QUAD:IN20:425:BMIN': BminVariable(name='QUAD:IN20:425:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE01'),
#  'QUAD:IN20:425:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:425:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE01'),
#  'QUAD:IN20:425:CTRL': ControlStateVariable(name='QUAD:IN20:425:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QE01'),
#  'QUAD:IN20:441:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:441:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE02'),
#  'QUAD:IN20:441:BCTRL.DRVL': BminVariable(name='QUAD:IN20:441:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE02'),
#  'QUAD:IN20:441:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:441:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE02'),
#  'QUAD:IN20:441:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:441:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE02'),
#  'QUAD:IN20:441:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:441:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE02'),
#  'QUAD:IN20:441:BMAX': BmaxVariable(name='QUAD:IN20:441:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE02'),
#  'QUAD:IN20:441:BMIN': BminVariable(name='QUAD:IN20:441:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE02'),
#  'QUAD:IN20:441:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:441:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE02'),
#  'QUAD:IN20:441:CTRL': ControlStateVariable(name='QUAD:IN20:441:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QE02'),
#  'QUAD:IN20:511:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:511:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE03'),
#  'QUAD:IN20:511:BCTRL.DRVL': BminVariable(name='QUAD:IN20:511:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE03'),
#  'QUAD:IN20:511:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:511:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE03'),
#  'QUAD:IN20:511:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:511:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE03'),
#  'QUAD:IN20:511:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:511:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE03'),
#  'QUAD:IN20:511:BMAX': BmaxVariable(name='QUAD:IN20:511:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE03'),
#  'QUAD:IN20:511:BMIN': BminVariable(name='QUAD:IN20:511:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE03'),
#  'QUAD:IN20:511:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:511:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE03'),
#  'QUAD:IN20:511:CTRL': ControlStateVariable(name='QUAD:IN20:511:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QE03'),
#  'QUAD:IN20:525:BCTRL': QuadrupoleBCTRLVariable(name='QUAD:IN20:525:BCTRL', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE04'),
#  'QUAD:IN20:525:BCTRL.DRVL': BminVariable(name='QUAD:IN20:525:BCTRL.DRVL', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE04'),
#  'QUAD:IN20:525:BCTRL.DRVH': BmaxVariable(name='QUAD:IN20:525:BCTRL.DRVH', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE04'),
#  'QUAD:IN20:525:BACT': QuadrupoleBACTVariable(name='QUAD:IN20:525:BACT', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE04'),
#  'QUAD:IN20:525:BDES': QuadrupoleBCTRLVariable(name='QUAD:IN20:525:BDES', read_only=False, default_validation_config='none', default_value=None, value_range=None, unit='kG', element_name='QE04'),
#  'QUAD:IN20:525:BMAX': BmaxVariable(name='QUAD:IN20:525:BMAX', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE04'),
#  'QUAD:IN20:525:BMIN': BminVariable(name='QUAD:IN20:525:BMIN', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE04'),
#  'QUAD:IN20:525:STATCTRLSUB.T': StatusVariable(name='QUAD:IN20:525:STATCTRLSUB.T', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='QE04'),
#  'QUAD:IN20:525:CTRL': ControlStateVariable(name='QUAD:IN20:525:CTRL', read_only=True, default_validation_config='none', default_value='Ready', options=['Ready', 'TRIM', 'PERTURB', 'BCON_TO_BDES', 'BACT_TO_BDES'], element_name='QE04'),
#  'OTRS:IN20:571:Image:ArrayData': ScreenImageVariable(name='OTRS:IN20:571:Image:ArrayData', read_only=True, default_validation_config='none', shape=(1040, 1392), dtype=dtype('float64'), default_value=None, unit=None, element_name='OTR2', pixel_size=1.2659999999999999e-05),
#  'OTRS:IN20:571:RESOLUTION': ScreenResolutionVariable(name='OTRS:IN20:571:RESOLUTION', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='OTR2', pixel_size=12.66, shape=(1040, 1392)),
#  'OTRS:IN20:571:Image:ArraySize0_RBV': ScreenImageShapeVariable(name='OTRS:IN20:571:Image:ArraySize0_RBV', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='OTR2', pixel_size=12.66, shape=(1040, 1392), index=1),
#  'OTRS:IN20:571:Image:ArraySize1_RBV': ScreenImageShapeVariable(name='OTRS:IN20:571:Image:ArraySize1_RBV', read_only=True, default_validation_config='none', default_value=None, value_range=None, unit=None, element_name='OTR2', pixel_size=12.66, shape=(1040, 1392), index=0)}
